# %%
# Imports
import pandas as pd

# %%
first_csv = 'TeamGameStats_2018REG_Week1.csv'
last_csv = 'TeamGameStats_2018REG_Week17.csv'

# %%
list_of_dfs = []

for n in range(1, 18):
    csv_file = f'CSV/TeamGameStats_2018REG_Week{n}.csv'
    df = pd.read_csv(csv_file)
    list_of_dfs.append(df)
    
final_df = pd.concat(list_of_dfs)

# %%
final_df
# Out:
#       GameKey                 Date  SeasonType  Season  Week Team Opponent  \
# 0   201810101  2018-09-09T16:25:00           1    2018     1  ARI      WAS
# 1   201810126  2018-09-06T20:20:00           1    2018     1  ATL      PHI
# 2   201810103  2018-09-09T13:00:00           1    2018     1  BAL      BUF
# 3   201810103  2018-09-09T13:00:00           1    2018     1  BUF      BAL
# 4   201810105  2018-09-09T16:25:00           1    2018     1  CAR      DAL
# 5   201810112  2018-09-09T20:20:00           1    2018     1  CHI       GB
# 6   201810114  2018-09-09T13:00:00           1    2018     1  CIN      IND
# 7   201810108  2018-09-09T13:00:00           1    2018     1  CLE      PIT
# 8   201810105  2018-09-09T16:25:00           1    2018     1  DAL      CAR
# 9   201810110  2018-09-09T16:25:00           1    2018     1  DEN      SEA
# 10  201810111  2018-09-10T19:10:00           1    2018     1  DET      NYJ
# ...

# %%
final_df.to_csv('CSV/nfl_2018.csv')
